# %%
import numpy as np
#作图
a=
y1 = -3
y2 = 0
E = np.linspace(0.001, 400, 1000) 
F_values = np.cos(2 * a * np.sqrt(E)) + y1 * np.sin(2 * a * np.sqrt(E)) / np.sqrt(E) - (y1**2 + y2**2) * (np.cos(2 * a * np.sqrt(E)) - 1) / (4 * E)

import matplotlib.pyplot as plt
plt.plot(E, F_values)
plt.ylim(-3,3)
plt.xlabel('E')
#plt.ylabel(f'F_1(E,y1={y1},y2={y2})')
plt.title(f'F_1(E,y1={y1},y2={y2})')
#plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       4 y2 = 0
#       5 E = np.linspace(0.001, 400, 1000)
# ----> 6 F_values = np.cos(2 * a * np.sqrt(E)) + y1 * np.sin(2 * a * np.sqrt(E)) / np.sqrt(E) - (y1**2 + y2**2) * (np.cos(2 * a * np.sqrt(E)) - 1) / (4 * E)
#       8 import matplotlib.pyplot as plt
#       9 plt.plot(E, F_values)
#
# NameError: name 'a' is not defined
