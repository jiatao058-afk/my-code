# %%
print('nihao')
# Out:
# nihao

# %%
a = {'a','b','c','d','a'}#创建集合a
print(a)#因为集合是无序不重复元素序列，所以不会输出多出的a
b = set('sdgssrfdsf')#运用Set()函数创建集合b
print(b)
# Out:
# {'c', 'a', 'b', 'd'}
# {'g', 's', 'f', 'r', 'd'}

# %%
a = set('sdfygsyfysdgfsdtfsyhf')
b = set('hgdhsdfsghdvhgsfs')
print(a,b)
print(a - b)
print(a | b)
print(a & b)
print(a ^ b)
# Out:
# {'t', 'y', 'g', 'h', 's', 'f', 'd'} {'g', 'h', 's', 'v', 'f', 'd'}
# {'t', 'y'}
# {'t', 'y', 'g', 'h', 's', 'v', 'f', 'd'}
# {'g', 'h', 's', 'f', 'd'}
# {'t', 'y', 'v'}

# %%
b = set('abcdefghijk,fuck,abats')
print(b)
b.remove('f')
print(b)
b.discard('h')
print(b)
b.pop()
print(b)
b.clear()
print(b)
# Out:
# {'j', 'u', 'k', 't', 'b', 'g', 'h', 's', 'e', ',', 'f', 'c', 'a', 'i', 'd'}
# {'j', 'u', 'k', 't', 'b', 'g', 'h', 's', 'e', ',', 'c', 'a', 'i', 'd'}
# {'j', 'u', 'k', 't', 'b', 'g', 's', 'e', ',', 'c', 'a', 'i', 'd'}
# {'u', 'k', 't', 'b', 'g', 's', 'e', ',', 'c', 'a', 'i', 'd'}
# set()

# %%
a = {'a':'Python','b':'347','c':'hjgjhfgy'}#创建一个字典
b = {'a':'HTML/Javascript','b':'Rust'}
print(b)
print(a['a'],a['c'])
# Out:
# {'a': 'HTML/Javascript', 'b': 'Rust'}
# Python hjgjhfgy

# %%
me = float(input())
wl = float(input())
if me < wl :
   print("WL赢了")
else :
   print("我赢了")
# Out:
#  1.1
#  12.2
# WL赢了

# %%
import random
a = 1
while a in [1,2,3,4,5,6]:
    b = int(random.random())
    c = int(input("猜数小游戏：请输入一个数字，看一下你猜不猜的中"))
    if c == b :
        print("恭喜你猜中了")
        a=a+1
    elif c > b :
        print("输入的数字太大了，再来一次",b)
        a=a+1
    elif c < b :
        print("输入的太小了，再输入大一点的数字，再来一次",b)
        a=a+1
# Out:
# 猜数小游戏：请输入一个数字，看一下你猜不猜的中 0
# 恭喜你猜中了
# 猜数小游戏：请输入一个数字，看一下你猜不猜的中 0
# 恭喜你猜中了
# 猜数小游戏：请输入一个数字，看一下你猜不猜的中 0
# 恭喜你猜中了
# 猜数小游戏：请输入一个数字，看一下你猜不猜的中 0
# 恭喜你猜中了
# 猜数小游戏：请输入一个数字，看一下你猜不猜的中 0
# 恭喜你猜中了
# 猜数小游戏：请输入一个数字，看一下你猜不猜的中 0
# 恭喜你猜中了

# %%
me = int(input())
wl = int(input())
if me == 520 and wl == 520 :
   print("就知道你爱我。")
else :
   print("这不是你的真心话。")
# Out:
#  520
#  22
# 这不是你的真心话。

# %%
me = int(input())
wl = int(input())
if me == 520 or wl == 520 :
   print("就知道你爱我。")
else :
   print("这不是你的真心话。")
# Out:
#  2
#  2
# 这不是你的真心话。

# %%
a=1
me = int(input())
wl = int(input())
if me  == 520 or wl == 520 :
   print("就知道你爱我。")
elif me == 99 or wl == 99 :
   print("不错")
   a=a+1
else :
   print("这不是你的真心话。")
print(a)
# Out:
#  5
#  99
# 不错
# 2

# %%
a=1
while a in [1]:
    me = int(input())
    wl = int(input())
    if me ==520 and wl != 520:
        print('这不是你的真心话')
    elif me > 5 and wl < 7:
        print('我跟你的相遇就像是酸遇上了碱，我们彼此中和，释放出了热与激情。')
        print('我对你的感情就像是钡离子与硫酸根的完美结合，生成了美好的感情沉淀。')
        print('我知道你的未来就像是Li  Na K Ru Cr Ba Ca Sr 的焰色反应一样五彩缤纷，最后希望你能像王水一样所向无敌，溶解掉所有的困难，走向成功。')
    elif me >= 64 and wl <= 103:
        print('我爱你，我会爱你爱到CuSO4 + Ba(OH)2=BaSO4↓+Cu(OH)2 ↓这两个产物无法分离提纯。')
    elif me and wl == 1314:
        print('我夺走了你的电子，请不要生气，我是为了更稳定的跟你结合在一起.')
    a=a+1
# Out:
#  1314
#  1314
# 我夺走了你的电子，请不要生气，我是为了更稳定的跟你结合在一起.

# %%
a=[1,2,3,4,5,6,7,8]
print(type(a))
for i in a:
	print(i)
# Out:
# <class 'list'>
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
a = '546dsf6d6sf74ds'
b=list(range(8))
print(b,type(b))
for i in range(len(a)):
    print(i,':',a[i])
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7] <class 'list'>
# 0 : 5
# 1 : 4
# 2 : 6
# 3 : d
# 4 : s
# 5 : f
# 6 : 6
# 7 : d
# 8 : 6
# 9 : s
# 10 : f
# 11 : 7
# 12 : 4
# 13 : d
# 14 : s

# %%
z1 = 3 + 4j
z2 = 2 - 3j
print(f'{z1} + {z2} = {z1 + z2}')
print(f'{z1} - {z2} = {z1 - z2}')
print(f'{z1} * {z2} = {z1 * z2}')
print(f'{z1} / {z2} = {z1 / z2}')
print(f'{z1}的共轭复数 = {z1.conjugate()}')
1/2
# Out:
# (3+4j) + (2-3j) = (5+1j)
# (3+4j) - (2-3j) = (1+7j)
# (3+4j) * (2-3j) = (18-1j)
# (3+4j) / (2-3j) = (-0.46153846153846156+1.3076923076923077j)
# (3+4j)的共轭复数 = (3-4j)
# 0.5

# %%
import math
a=1
b=math.exp(a)
print(b)
# Out:
# 2.718281828459045

# %%
import numpy as np
import matplotlib.pyplot as plt

# 设定参数
f = 5  # 频率为5 Hz
omega = 2 * np.pi * f  # 角频率 ω = 2πf
t = np.linspace(0, 1, 1000)  # 生成时间向量，从0到1秒，共1000个点

# 生成两个复数指数信号
x_1 = np.exp(1j * omega * t)  # x_1(t) = e^(jΩt)
x_2 = np.exp(-1j * omega * t)  # x_2(t) = e^(-jΩt)

# 提取信号的幅度和相位
amplitude_x_1 = np.abs(x_1)  # x_1的幅度
phase_x_1 = np.angle(x_1)  # x_1的相位

amplitude_x_2 = np.abs(x_2)  # x_2的幅度
phase_x_2 = np.angle(x_2)  # x_2的相位

# 绘制幅度和相位
plt.figure(figsize=(12, 6))

# 绘制x_1的波形、振幅和相位
plt.subplot(3, 2, 1)
plt.plot(t, x_1)
plt.title("x_1的波形")
plt.xlabel("时间 (s)")
plt.ylabel("幅度")

plt.subplot(3, 2, 3)
plt.plot(t, amplitude_x_1)
plt.title("x_1的振幅")
plt.xlabel("时间 (s)")
plt.ylabel("振幅")

plt.subplot(3, 2, 5)
plt.plot(t, phase_x_1)
plt.title("x_1的相位")
plt.xlabel("时间 (s)")
plt.ylabel("相位 (rad)")

# 绘制x_2的波形、振幅和相位
plt.subplot(3, 2, 2)
plt.plot(t, x_2)
plt.title("x_2的波形")
plt.xlabel("时间 (s)")
plt.ylabel("幅度")

plt.subplot(3, 2, 4)
plt.plot(t, amplitude_x_2)
plt.title("x_2的振幅")
plt.xlabel("时间 (s)")
plt.ylabel("振幅")

plt.subplot(3, 2, 6)
plt.plot(t, phase_x_2)
plt.title("x_2的相位")
plt.xlabel("时间 (s)")
plt.ylabel("相位 (rad)")

# 使用tight_layout自动调整子图参数，避免标签之间的重叠
plt.tight_layout()  
# 在所有子图上添加网格线
plt.grid(True)
# 显示绘制的图像
plt.show()
# Out:
# C:\Users\taoji\AppData\Local\Temp\ipykernel_7732\1145105025.py:62: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from current font.
#   plt.tight_layout()
# C:\Users\taoji\AppData\Local\Temp\ipykernel_7732\1145105025.py:62: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from current font.
#   plt.tight_layout()
# C:\Users\taoji\AppData\Local\Temp\ipykernel_7732\1145105025.py:62: UserWarning: Glyph 24133 (\N{CJK UNIFIED IDEOGRAPH-5E45}) missing from current font.
#   plt.tight_layout()
# C:\Users\taoji\AppData\Local\Temp\ipykernel_7732\1145105025.py:62: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from current font.
#   plt.tight_layout()
# C:\Users\taoji\AppData\Local\Temp\ipykernel_7732\1145105025.py:62: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from current font.
#   plt.tight_layout()
# ...

# %%
t = np.linspace(0, 1, 1000)
print(t)
# Out:
# [0.         0.001001   0.002002   0.003003   0.004004   0.00500501
#  0.00600601 0.00700701 0.00800801 0.00900901 0.01001001 0.01101101
#  0.01201201 0.01301301 0.01401401 0.01501502 0.01601602 0.01701702
#  0.01801802 0.01901902 0.02002002 0.02102102 0.02202202 0.02302302
#  0.02402402 0.02502503 0.02602603 0.02702703 0.02802803 0.02902903
#  0.03003003 0.03103103 0.03203203 0.03303303 0.03403403 0.03503504
#  0.03603604 0.03703704 0.03803804 0.03903904 0.04004004 0.04104104
#  0.04204204 0.04304304 0.04404404 0.04504505 0.04604605 0.04704705
#  0.04804805 0.04904905 0.05005005 0.05105105 0.05205205 0.05305305
#  0.05405405 0.05505506 0.05605606 0.05705706 0.05805806 0.05905906
#  0.06006006 0.06106106 0.06206206 0.06306306 0.06406406 0.06506507
#  0.06606607 0.06706707 0.06806807 0.06906907 0.07007007 0.07107107
#  0.07207207 0.07307307 0.07407407 0.07507508 0.07607608 0.07707708
#  0.07807808 0.07907908 0.08008008 0.08108108 0.08208208 0.08308308
# ...

# %%
a=5
b=2
def add_numbers(a, b):
    """计算两个数的和"""
    result = a + b
    return result
add_numbers(a, b)
# Out:
# 7

# %%
def greet(name, age=18):
    print(f"Hello, {name}. You are {age} years old.")

# Bob 进入房间，但我们不知道他的年龄，所以使用默认值 18
print("Bob 走进了房间...")
greet("Bob")  # 输出：Hello, Bob. You are 18 years old.

# Charlie 进入房间并告诉我们他30岁了
print("Charlie 走进了房间并说他30岁了...")
greet("Charlie", 30)  # 输出：Hello, Charlie. You are 30 years old.
# Out:
# Bob 走进了房间...
# Hello, Bob. You are 18 years old.
# Charlie 走进了房间并说他30岁了...
# Hello, Charlie. You are 30 years old.

# %%
def func(*args, **kwargs):
    print("位置参数:", args)
    print("关键字参数:", kwargs)

# 我们有一个函数 func，它接受任意数量的位置参数和关键字参数
print("我们调用 func 函数，传入一些参数...")
func(1, 2, 3, a=4, b=5)

# 输出：
# 位置参数: (1, 2, 3)
# 关键字参数: {'a': 4, 'b': 5}
# Out:
# 我们调用 func 函数，传入一些参数...
# 位置参数: (1, 2, 3)
# 关键字参数: {'a': 4, 'b': 5}

# %%
def greet(name):
    print(f"Hello, {name}!")

def call_function(func, arg):
    func(arg)

call_function(greet, "World")  # 输出：Hello, World!
# Out:
# Hello, World!

# %%
add = lambda x, y: x + y
print(add(3, 5))  # 输出：8
# Out:
# 8

# %%
import numpy as np
import matplotlib.pyplot as plt

# 设定参数
f = 5  # 频率为5 Hz
omega = 2 * np.pi * f  # 角频率 ω = 2πf
t = np.linspace(0, 1, 1000)  # 生成时间向量，从0到1秒，共1000个点

# 生成两个复数指数信号
x_1 = np.exp(1j * omega * t)  # x_1(t) = e^(jΩt)
x_2 = np.exp(-1j * omega * t)  # x_2(t) = e^(-jΩt)
print(type(x_1))
# Out:
# <class 'numpy.ndarray'>

# %%
import numpy as np
x = np.array([[1, 0], [2, 0], [3, 1]], np.int32)
print(x)
print(x[1][1])
'''
程序输出：
[[1 0]
 [2 0]
 [3 1]]
int32
'''
# Out:
# [[1 0]
#  [2 0]
#  [3 1]]
# 0
# '\n程序输出：\n[[1 0]\n [2 0]\n [3 1]]\nint32\n'

# %%
import numpy as np
result1 = np.array([[1, 2], [1, 3]], np.complex128)
result2 = np.array([[1, 4], [1, 5]], np.complex128)
def coupling(matrix_1,matrix_2):                         #  matrix coupling
    s11_1=matrix_1[0][0]
    s12_1=matrix_1[0][1]
    s21_1=matrix_1[1][0]
    s22_1=matrix_1[1][1]
    s11_2=matrix_2[0][0]
    s12_2=matrix_2[0][1]
    s21_2=matrix_2[1][0]
    s22_2=matrix_2[1][1]
    s11=s11_1+s12_1*s21_1*s11_2/(1-s11_2*s22_1)
    s12=s12_1*s12_2/(1-s11_2*s22_1)
    s21=s21_2*s21_1/(1-s11_2*s22_1)
    s22=s22_2+s21_2*s12_2*s22_1/(1-s11_2*s22_1)
    result = np.array([[s11, s12], [s21, s22]], np.complex128)
    return result
coupling(result1,result1)
# Out:
# array([[ 0. +0.j, -2. -0.j],
#        [-0.5-0.j,  0. +0.j]])

# %%
m=complex(9.1093837*10**(-31))
h=6.62607015*10**(-34)
h1=complex(h/(2*np.pi))
E=complex(1.602*10**(-19))
k=(2*m*E/(h1**2))**0.5
print(k,'k',h1,'h1',m,'m')
x_0=0.5-1
x_1=0.5
location = np.linspace(x_0, x_1, 2)
print(location,'location')
N=2
period=np.arange(N)
print(period,'period')             #period
matrix_collect = np.zeros((N, 2, 2), dtype=complex)
print(matrix_collect,type(matrix_collect),'matrix_collect') #matrix_collect
y=complex(1.602*10**(-19))*6.3
di=np.arange(0,N,dtype=complex)
constant_1=2*m*y/(h1**2)
print(constant_1*(0+1j),di,np.arange(N))
for i in np.arange(N):
    di[i]=(1j)*constant_1*(-1)**i
print(di,'di')
for i in period:
    s11=1j*k*np.exp(2j*k*location[i])+k**2+di[i]**2
    s12=(-1j)*k+(k**2+1j*k*di[i])*np.exp((-2j)*k*location[i])
    s21=(-1)+(-1j*k)+(-di[i])
    s22=1-1j*k
    if i==len(period)-1:
        s12=0
        s22=0
    matrix_3= np.array([[s11, s12], [s21, s22]])
    matrix_collect[i]=matrix_3
#    print(matrix_3)
print(matrix_collect)
# Out:
# (5122884806.427367+0j) k (1.0545718176461565e-34+0j) h1 (9.109383700000002e-31+0j) m
# [-0.5  0.5] location
# [0 1] period
# [[[0.+0.j 0.+0.j]
#   [0.+0.j 0.+0.j]]
#
#  [[0.+0.j 0.+0.j]
#   [0.+0.j 0.+0.j]]] <class 'numpy.ndarray'> matrix_collect
# 1.653368770615235e+20j [0.+0.j 1.+0.j] [0 1]
# [ 0.+1.65336877e+20j -0.-1.65336877e+20j] di
# [[[-2.73362829e+40+2.56003589e+09j -4.23268340e+29+7.33659267e+29j]
#   [-1.00000000e+00-1.65336877e+20j  1.00000000e+00-5.12288481e+09j]]
#
#  [[-2.73362829e+40+2.56003589e+09j  0.00000000e+00+0.00000000e+00j]
#   [-1.00000000e+00+1.65336877e+20j  0.00000000e+00+0.00000000e+00j]]]

# %%
matrix4=matrix_collect[0]
matrix5=matrix_collect[1]
print(matrix4,'\n',matrix5)
a=coupling(matrix4,matrix5)
print(a)
# Out:
# [[-2.73362829e+40+2.56003589e+09j -4.23268340e+29+7.33659267e+29j]
#  [-1.00000000e+00-1.65336877e+20j  1.00000000e+00-5.12288481e+09j]]
#  [[-2.73362829e+40+2.56003589e+09j  0.00000000e+00+0.00000000e+00j]
#  [-1.00000000e+00+1.65336877e+20j  0.00000000e+00+0.00000000e+00j]]
# [[-1.36756468e+40-2.36782470e+40j -0.00000000e+00-0.00000000e+00j]
#  [ 3.81040220e-20+1.95202515e-10j  0.00000000e+00+0.00000000e+00j]]

# %%
print(abs(a[0][0]),abs(a[1][0]),abs(a[0][0])+abs(a[1][0]))
# Out:
# 2.734378718135682e+40 1.9520251533771788e-10 2.734378718135682e+40
